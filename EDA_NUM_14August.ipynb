# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as scn

# %%
path=r'C:\Users\manish\Datafile\Visadataset.csv'
visa_df=pd.read_csv(path)
visa_df.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %%
cat_columns=visa_df.select_dtypes(include='object').columns
num_columns=visa_df.select_dtypes(exclude='object').columns

# %% [markdown]
# **Num vs Num**
# - to understand num col relation we need dto plot scatter plots
# - scatter plots gives the relation bt two num col
# - Bar chart- pie chart- hist - scatter plots
# - scatter plots under matplotlib package
# - **plt.scatter**

# %%
x=[1,2,3,4,5]
y=[1,2,3,4,5]
plt.scatter(x=x,y=y)
plt.plot(x,y)

# %% [markdown]
# **Parabola**

# %%
x=[i for i in range(-10,11)]
y=[i*i for i in x]
plt.scatter(x=x,y=y)
plt.plot(x,y)

# %%
# step_1: read the num col
# step2: read another numerical col

# %%
num_columns
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %%
emp=visa_df['no_of_employees']
year=visa_df['yr_of_estab']
plt.scatter(x=emp,y=wage)

# %%
emp=visa_df['no_of_employees']
wage=visa_df['prevailing_wage']
plt.scatter(x=emp,y=wage)

# %%
visa_df.corr(numeric_only=True)
# Out:
#                  no_of_employees  yr_of_estab  prevailing_wage
# no_of_employees         1.000000    -0.017770        -0.009523
# yr_of_estab            -0.017770     1.000000         0.012342
# prevailing_wage        -0.009523     0.012342         1.000000

# %% [markdown]
# **Heat map**
# - heat map is one of  the visulization method, to show the matrix form of values
# - its under seaborn package
# - In every matrix we have highest values and the lowest values available
# - heat map will give colour visulization
# - also its provide color bar, which colour indicates

# %%
corr_data=visa_df.corr(numeric_only=True)
scn.heatmap(corr_data,annot=True)
plt.show()

# %% [markdown]
# **Observation**
# - by seeing the grapgh we might not say the relation status
# - it is best practice get the percentage of relation using co_relation
# - all 3 col having approximately zero% relation
# - No relation means independent each other
# - in ml we except the input col should be independent
